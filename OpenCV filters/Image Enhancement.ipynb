# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
img = cv2.imread('1.jpg')

# %%
col = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(col)

# %%
#Image Denoising
dst = cv2.fastNlMeansDenoisingColored(col, None, 11, 6, 7, 21)

# %%
plt.imshow(dst)

# %%
img = dst
#image = cv2.cvtColor(dst,cv2.COLOR_BGR2RGB)
#image = cv2.cvtColor(dst)

plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img)


kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

#sharpened_image = cv2.Laplacian(image, cv2.CV_64F)
sharpened_image = cv2.filter2D(img, -1, kernel)


cv2.imwrite('sharpened_image.jpg', sharpened_image)


plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)
plt.show()

# %%
img = cv2.imread('1.jpg')
#image = cv2.cvtColor(dst,cv2.COLOR_BGR2RGB)
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#image = dst
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)


kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

#sharpened_image = cv2.Laplacian(image, cv2.CV_64F)
sharpened_image = cv2.filter2D(image, -1, kernel)


cv2.imwrite('sharpened_image1.jpg', sharpened_image)


plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)
plt.show()

# %%
#Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
img = cv2.imread('Original_3.jpg')
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

#Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)


image[:, :, 0] = image[:, :, 0] * 0.7

image[:, :, 1] = image[:, :, 1] * 1.5

image[:, :, 2] = image[:, :, 2] * 0.5


image2 = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

sharpened_image = cv2.filter2D(image2, -1, kernel)


#Save the image
cv2.imwrite('enhanced coloured.jpg', sharpened_image)

#Plot the enhanced image
plt.subplot(1, 2, 2)
plt.title("enhanced coloured")
plt.imshow(image2)
plt.show()

# %%
img = cv2.imread('1.jpg')

gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap="Greys_r")

# %%
plt.hist(gray.ravel(),256,[0,256])
plt.show()

# %%
dst = cv2.equalizeHist(gray)

# %%
plt.imshow(dst, cmap='Greys_r')

# %%
plt.hist(dst.ravel(),256,[0,256])
plt.show()
